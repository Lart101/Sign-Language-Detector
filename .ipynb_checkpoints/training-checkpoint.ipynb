# %%
from ultralytics import YOLO

# Load a model
model = YOLO("yolo11n.pt")

# Train the model
train_results = model.train(
    data=r"C:\Capstone\Models\American Sign Language Letters.v1-v1.yolov11\data.yaml",  # Path to dataset YAML
    epochs=100,              # Number of training epochs (increase for better accuracy)
    imgsz=640,               # Training image size (640 is standard, but adjust if needed)
    batch=16,                # Batch size (adjust based on GPU memory)
    device='cuda',           # Use GPU for faster training (e.g., 'cuda' or '0')
    workers=8,               # Number of worker threads for data loading
    lr0=0.01,                # Initial learning rate (start with 0.01 for fine-tuning)
    optimizer='SGD',         # Optimizer (SGD is robust; Adam can also work)
    augment=True,            # Enable data augmentation for better generalization
    cache=True,              # Cache images in memory for faster training
    patience=50,             # Early stopping patience (stop if no improvement after 50 epochs)
    project='runs/train',    # Directory to save results
    name='exp',              # Experiment name
    exist_ok=False,          # Overwrite existing experiment directory
    pretrained=True,         # Start from a pre-trained model
    resume=False,            # Resume training from last checkpoint
    verbose=True             # Print detailed logs during training
)
# Out:
# Ultralytics 8.3.70  Python-3.13.1 torch-2.6.0+cpu CPU (12th Gen Intel Core(TM) i5-12500H)
# engine\trainer: task=detect, mode=train, model=yolo11n.pt, data=C:\Capstone\SignLang\yolo11\Models/HandSignDetection.v1i.yolov11/data.yaml, epochs=5, time=None, patience=100, batch=16, imgsz=640, save=True, save_period=-1, cache=False, device=cpu, workers=8, project=None, name=train12, exist_ok=False, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, multi_scale=False, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, vid_stride=1, stream_buffer=False, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, embed=None, show=False, save_frames=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, show_boxes=True, line_width=None, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=True, opset=None, workspace=None, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, bgr=0.0, mosaic=1.0, mixup=0.0, copy_paste=0.0, copy_paste_mode=flip, auto_augment=randaugment, erasing=0.4, crop_fraction=1.0, cfg=None, tracker=botsort.yaml, save_dir=runs\detect\train12
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\engine\trainer.py:562, in BaseTrainer.get_dataset(self)
#     556 elif self.args.data.split(".")[-1] in {"yaml", "yml"} or self.args.task in {
#     557     "detect",
#     558     "segment",
#     559     "pose",
#     560     "obb",
#     561 }:
# --> 562     data = check_det_dataset(self.args.data)
#     563     if "yaml_file" in data:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\data\utils.py:316, in check_det_dataset(dataset, autodownload)
#     302 """
#     303 Download, verify, and/or unzip a dataset if not found locally.
#     304
#    (...)
#     314     (dict): Parsed dataset information and paths.
#     315 """
# --> 316 file = check_file(dataset)
#     318 # Download (optional)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\utils\checks.py:522, in check_file(file, suffix, download, download_dir, hard)
#     521 if not files and hard:
# --> 522     raise FileNotFoundError(f"'{file}' does not exist")
#     523 elif len(files) > 1 and hard:
#
# FileNotFoundError: 'C:\Capstone\SignLang\yolo11\Models/HandSignDetection.v1i.yolov11/data.yaml' does not exist
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# Cell In[1], line 7
#       4 model = YOLO("yolo11n.pt")
#       6 # Train the model
# ----> 7 train_results = model.train(
#       8     data=r"C:\Capstone\SignLang\yolo11\Models/HandSignDetection.v1i.yolov11/data.yaml",  # path to dataset YAML
#       9     epochs=5,  # number of training epochs
#      10     imgsz=640,  # training image size
#      11     device='cpu',  # device to run on, i.e. device=0 or device=0,1,2,3 or device=cpu
#      12 )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\engine\model.py:802, in Model.train(self, trainer, **kwargs)
#     799 if args.get("resume"):
#     800     args["resume"] = self.ckpt_path
# --> 802 self.trainer = (trainer or self._smart_load("trainer"))(overrides=args, _callbacks=self.callbacks)
#     803 if not args.get("resume"):  # manually set model only if not resuming
#     804     self.trainer.model = self.trainer.get_model(weights=self.model if self.ckpt else None, cfg=self.model.yaml)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\engine\trainer.py:133, in BaseTrainer.__init__(self, cfg, overrides, _callbacks)
#     131 self.model = check_model_file_from_stem(self.args.model)  # add suffix, i.e. yolo11n -> yolo11n.pt
#     132 with torch_distributed_zero_first(LOCAL_RANK):  # avoid auto-downloading dataset multiple times
# --> 133     self.trainset, self.testset = self.get_dataset()
#     134 self.ema = None
#     136 # Optimization utils init
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\engine\trainer.py:566, in BaseTrainer.get_dataset(self)
#     564             self.args.data = data["yaml_file"]  # for validating 'yolo train data=url.zip' usage
#     565 except Exception as e:
# --> 566     raise RuntimeError(emojis(f"Dataset '{clean_url(self.args.data)}' error ❌ {e}")) from e
#     567 self.data = data
#     568 return data["train"], data.get("val") or data.get("test")
#
# RuntimeError: Dataset 'C://Capstone/SignLang/yolo11/Models/HandSignDetection.v1i.yolov11/data.yaml' error  'C:\Capstone\SignLang\yolo11\Models/HandSignDetection.v1i.yolov11/data.yaml' does not exist

# %%
from ultralytics import YOLO

# Load a model
model = YOLO("runs/detect/train9/weights/best.pt")

# Perform object detection on an image
results = model("test_images/b1.jpg", save=True)
results[0].show()
# Out:
# image 1/1 C:\Capstone\test_images\b1.jpg: 640x640 1 B, 171.0ms
# Speed: 2.5ms preprocess, 171.0ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs\detect\predict6

# %%
from ultralytics import YOLO
import cv2

# Load the trained YOLO model
model = YOLO("runs/detect/train9/weights/best.pt")

# Open the webcam (usually 0 for the default camera)
cap = cv2.VideoCapture(0)

# Check if the webcam is opened correctly
if not cap.isOpened():
    print("Error: Could not open webcam.")
    exit()

# Set desired resolution for better accuracy (optional)
cap.set(cv2.CAP_PROP_FRAME_WIDTH, 640)  # Width
cap.set(cv2.CAP_PROP_FRAME_HEIGHT, 480)  # Height

print("Starting real-time detection. Press 'q' to quit.")

# Loop to capture frames from the webcam
while True:
    # Capture frame-by-frame
    ret, frame = cap.read()

    # If the frame was not captured successfully, break the loop
    if not ret:
        print("Error: Failed to capture frame.")
        break

    # Perform object detection on the current frame
    results = model(frame)  # Pass the frame to the YOLO model

    # Extract detailed information from the results
    annotated_frame = results[0].plot()  # Get the annotated frame with bounding boxes
    detected_objects = []

    for result in results:
        boxes = result.boxes  # Bounding boxes
        for box in boxes:
            class_id = int(box.cls)  # Class ID of the detected object
            label = model.names[class_id]  # Get the class name from the model
            confidence = float(box.conf)  # Confidence score
            x1, y1, x2, y2 = map(int, box.xyxy[0])  # Bounding box coordinates

            # Store detected object details
            detected_objects.append({
                "label": label,
                "confidence": confidence,
                "x1": x1,
                "y1": y1,
                "x2": x2,
                "y2": y2
            })

    # Display the annotated frame in a window
    cv2.imshow("YOLO Real-Time Detection", annotated_frame)

    # Print detected objects to the console for debugging
    if detected_objects:
        print("Detected Objects:")
        for obj in detected_objects:
            print(f"Label: {obj['label']}, Confidence: {obj['confidence']:.2f}, "
                  f"Box: ({obj['x1']}, {obj['y1']}) -> ({obj['x2']}, {obj['y2']})")
    else:
        print("No objects detected.")

    # Break the loop if 'q' key is pressed
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release the webcam and close all OpenCV windows
cap.release()
cv2.destroyAllWindows()
# Out:
# Starting real-time detection. Press 'q' to quit.
#
# 0: 480x640 (no detections), 155.5ms
# Speed: 3.0ms preprocess, 155.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
# No objects detected.
#
# 0: 480x640 (no detections), 116.1ms
# Speed: 4.8ms preprocess, 116.1ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
# No objects detected.
#
# 0: 480x640 (no detections), 134.6ms
# Speed: 2.9ms preprocess, 134.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
# No objects detected.
#
# 0: 480x640 (no detections), 121.3ms
# Speed: 1.6ms preprocess, 121.3ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
# No objects detected.
#
# 0: 480x640 (no detections), 125.4ms
# Speed: 2.0ms preprocess, 125.4ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
# No objects detected.
#
# 0: 480x640 (no detections), 153.2ms
# Speed: 4.8ms preprocess, 153.2ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
# No objects detected.
#
# 0: 480x640 (no detections),
8ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
# No objects detected.
#
# 0: 480x640 (no detections), 106.1ms
# Speed: 1.3ms preprocess, 106.1ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# No objects detected.
#
# 0: 480x640 (no detections), 81.0ms
# Speed: 1.3ms preprocess, 81.0ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# No objects detected.
#
# 0: 480x640 (no detections), 78.4ms
# Speed: 1.2ms preprocess, 78.4ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# No objects detected.
#
# 0: 480x640 (no detections), 76.7ms
# Speed: 1.1ms preprocess, 76.7ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
# No objects detected.
#
# 0: 480x640 (no detections), 84.8ms
# Speed: 2.1ms preprocess, 84.8ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
# No objects detected.
#
# 0: 480x640 (no detections), 81.8ms
# Speed: 1.5ms preprocess, 81.8ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
# No objects detected.
#
# 0: 480x640 (no detections), 77.7ms
# Speed: 1.1ms preprocess, 77.7ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# No objects detected.
#
# 0: 480x640 (no detections), 110.8ms
# Speed: 2.0ms preprocess, 110.8ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
# No objects detected.
#
# 0: 480x640 1 L, 104.0ms
# Speed: 1.9ms preprocess, 104.0ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
# Detected Objects:
# Label: L, Confidence: 0.32, Box: (35, 125) -> (577, 473)
#
# 0: 480x640 (no detections), 78.4ms
# Speed: 1.8ms preprocess, 78.4ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
# No objects detected.
#
# 0: 480x640 (no detections), 81.4ms
# Speed: 1.2ms preprocess, 81.4ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# No objects detected.
#
# 0: 480x640 (no detections), 84.3ms
# Speed: 1.7ms preprocess, 84.3ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# No objects detected.
#
# 0: 480x640 (no detections), 85.6ms
# Speed: 1.6ms preprocess, 85.6ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# No objects detected.
#
# 0: 480x640 (no detections), 81.1ms
# Speed: 1.6ms preprocess, 81.1ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
# No objects detected.
#
# 0: 480x640 (no detections), 79.7ms
# Speed: 2.2ms preprocess, 79.7ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
# No objects detected.
#
# 0: 480x640 (no detections), 82.1ms
# Speed: 1.1ms preprocess, 82.1ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
# No objects detected.
#
# 0: 480x640 (no detections), 87.6ms
# Speed: 1.1ms preprocess, 87.6ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# No objects detected.
#
# 0: 480x640 (no detections), 78.0ms
# Speed: 1.3ms preprocess, 78.0ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# No objects detected.
#
# 0: 480x640 (no detections), 78.1ms
# Speed: 1.3ms preprocess, 78.1ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# No objects detected.
#
# 0: 480x640 (no detections), 88.7ms
# Speed: 1.4ms preprocess, 88.7ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# No objects detected.
#
# 0: 480x640 (no detections), 93.8ms
# Speed: 1.9ms preprocess, 93.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
# No objects detected.
#
# 0: 480x640 1 L, 81.3ms
# Speed: 1.1ms preprocess, 81.3ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
# Detected Objects:
# Label: L, Confidence: 0.25, Box: (3, 103) -> (568, 471)
#
# 0: 480x640 1 L, 89.3ms
# Speed: 1.2ms preprocess, 89.3ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
# Detected Objects:
# Label: L, Confidence: 0.25, Box: (3, 103) -> (568, 471)
#
# 0: 480x640 (no detections), 93.8ms
# Speed: 1.7ms preprocess, 93.8ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# No objects detected.
#
# 0: 480x640 (no detections), 90.2ms
# Speed: 1.1ms preprocess, 90.2ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# No objects detected.
#
# 0: 480x640 (no detections), 98.2ms
# Speed: 1.6ms preprocess, 98.2ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# No objects detected.
#
# 0: 480x640 (no detections), 83.8ms
# Speed: 1.3ms preprocess, 83.8ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# No objects detected.
#
# 0: 480x640 (no detections), 99.6ms
# Speed: 1.1ms preprocess, 99.6ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# No objects detected.
#
# 0: 480x640 (no detections), 81.4ms
# Speed: 1.5ms preprocess, 81.4ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
# No objects detected.
#
# 0: 480x640 (no detections), 78.8ms
# Speed: 1.8ms preprocess, 78.8ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# No objects detected.
#
# 0: 480x640 (no detections), 86.5ms
# Speed: 1.5ms preprocess, 86.5ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# No objects detected.
#
# 0: 480x640 (no detections), 86.7ms
# Speed: 1.8ms preprocess, 86.7ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
# No objects detected.
#
# 0: 480x640 (no detections), 76.9ms
# Speed: 1.5ms preprocess, 76.9ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# No objects detected.
#
# 0: 480x640 (no detections), 96.5ms
# Speed: 1.1ms preprocess, 96.5ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
# No objects detected.
#
# 0: 480x640 (no detections), 77.1ms
# Speed: 1.6ms preprocess, 77.1ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
# No objects detected.
#
# 0: 480x640 (no detections), 81.6ms
# Speed: 1.1ms preprocess, 81.6ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# No objects detected.
#
# 0: 480x640 (no detections), 95.2ms
# Speed: 1.2ms preprocess, 95.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
# No objects detected.
#
# 0: 480x640 (no detections), 86.8ms
# Speed: 1.8ms preprocess, 86.8ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# No objects detected.
#
# 0: 480x640 (no detections), 79.4ms
# Speed: 1.6ms preprocess, 79.4ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# No objects detected.
#
# 0: 480x640 (no detections), 81.3ms
# Speed: 1.1ms preprocess, 81.3ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# No objects detected.
#
# 0: 480x640 1 L, 77.2ms
# Speed: 1.2ms preprocess, 77.2ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
# Detected Objects:
# Label: L, Confidence: 0.27, Box: (2, 112) -> (578, 469)
#
# 0: 480x640 1 L, 85.4ms
# Speed: 1.3ms preprocess, 85.4ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
# Detected Objects:
# Label: L, Confidence: 0.27, Box: (2, 112) -> (578, 469)
#
# 0: 480x640 (no detections), 109.9ms
# Speed: 1.7ms preprocess, 109.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
# No objects detected.
#
# 0: 480x640 (no detections), 92.6ms
# Speed: 1.3ms preprocess, 92.6ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
# No objects detected.
#
# 0: 480x640 1 L, 79.2ms
# Speed: 1.1ms preprocess, 79.2ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
# Detected Objects:
# Label: L, Confidence: 0.33, Box: (5, 105) -> (573, 476)
#
# 0: 480x640 (no detections), 82.0ms
# Speed: 1.0ms preprocess, 82.0ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# No objects detected.
#
# 0: 480x640 1 L, 108.6ms
# Speed: 1.3ms preprocess, 108.6ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
# Detected Objects:
# Label: L, Confidence: 0.27, Box: (7, 100) -> (593, 457)
#
# 0: 480x640 (no detections), 81.1ms
# Speed: 1.4ms preprocess, 81.1ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
# No objects detected.
#
# 0: 480x640 (no detections), 98.2ms
# Speed: 1.8ms preprocess, 98.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# No objects detected.
#
# 0: 480x640 (no detections), 82.5ms
# Speed: 1.6ms preprocess, 82.5ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# No objects detected.
#
# 0: 480x640 (no detections), 76.8ms
# Speed: 1.1ms preprocess, 76.8ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
# No objects detected.
#
# 0: 480x640 (no detections), 88.1ms
# Speed: 1.3ms preprocess, 88.1ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
# No objects detected.
#
# 0: 480x640 (no detections), 81.8ms
# Speed: 1.5ms preprocess, 81.8ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# No objects detected.
#
# 0: 480x640 (no detections), 80.6ms
# Speed: 1.1ms preprocess, 80.6ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# No objects detected.
#
# 0: 480x640 (no detections), 84.2ms
# Speed: 1.8ms preprocess, 84.2ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
# No objects detected.
#
# 0: 480x640 (no detections), 82.3ms
# Speed: 1.4ms preprocess, 82.3ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# No objects detected.
#
# 0: 480x640 1 L, 84.4ms
# Speed: 1.4ms preprocess, 84.4ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
# Detected Objects:
# Label: L, Confidence: 0.31, Box: (7, 110) -> (598, 466)
#
# 0: 480x640 1 L, 82.2ms
# Speed: 2.6ms preprocess, 82.2ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
# Detected Objects:
# Label: L, Confidence: 0.38, Box: (3, 106) -> (561, 465)
#
# 0: 480x640 1 L, 81.7ms
# Speed: 3.8ms preprocess, 81.7ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
# Detected Objects:
# Label: L, Confidence: 0.38, Box: (3, 106) -> (561, 465)
#
# 0: 480x640 1 L, 92.6ms
# Speed: 1.3ms preprocess, 92.6ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
# Detected Objects:
# Label: L, Confidence: 0.37, Box: (7, 101) -> (596, 464)
#
# 0: 480x640 1 L, 77.3ms
# Speed: 1.2ms preprocess, 77.3ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
# Detected Objects:
# Label: L, Confidence: 0.32, Box: (3, 107) -> (575, 463)
#
# 0: 480x640 (no detections), 82.3ms
# Speed: 1.2ms preprocess, 82.3ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# No objects detected.
#
# 0: 480x640 (no detections), 82.1ms
# Speed: 2.5ms preprocess, 82.1ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
# No objects detected.
#
# 0: 480x640 (no detections), 99.9ms
# Speed: 1.1ms preprocess, 99.9ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
# No objects detected.
#
# 0: 480x640 (no detections), 92.5ms
# Speed: 1.2ms preprocess, 92.5ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
# No objects detected.
#
# 0: 480x640 (no detections), 84.5ms
# Speed: 1.7ms preprocess, 84.5ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# No objects detected.
#
# 0: 480x640 (no detections), 93.2ms
# Speed: 1.7ms preprocess, 93.2ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
# No objects detected.
#
# 0: 480x640 (no detections), 81.4ms
# Speed: 1.4ms preprocess, 81.4ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# No objects detected.
#
# 0: 480x640 (no detections), 81.1ms
# Speed: 1.4ms preprocess, 81.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# No objects detected.
#
# 0: 480x640 (no detections), 105.6ms
# Speed: 1.7ms preprocess, 105.6ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# No objects detected.
#
# 0: 480x640 (no detections), 88.1ms
# Speed: 2.0ms preprocess, 88.1ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
# No objects detected.
#
# 0: 480x640 (no detections), 83.1ms
# Speed: 1.8ms preprocess, 83.1ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# No objects detected.
#
# 0: 480x640 (no detections), 83.3ms
# Speed: 1.0ms preprocess, 83.3ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# No objects detected.
#
# 0: 480x640 (no detections), 89.7ms
# Speed: 1.1ms preprocess, 89.7ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
# No objects detected.
#
# 0: 480x640 (no detections), 80.6ms
# Speed: 1.4ms preprocess, 80.6ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
# No objects detected.
#
# 0: 480x640 (no detections), 79.3ms
# Speed: 1.1ms preprocess, 79.3ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
# No objects detected.
#
# 0: 480x640 (no detections), 89.1ms
# Speed: 1.3ms preprocess, 89.1ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
# No objects detected.
#
# 0: 480x640 (no detections), 81.9ms
# Speed: 2.0ms preprocess, 81.9ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# No objects detected.
#
# 0: 480x640 (no detections), 86.2ms
# Speed: 2.4ms preprocess, 86.2ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# No objects detected.
#
# 0: 480x640 (no detections), 78.9ms
# Speed: 1.6ms preprocess, 78.9ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# No objects detected.
#
# 0: 480x640 (no detections), 81.4ms
# Speed: 1.6ms preprocess, 81.4ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# No objects detected.
#
# 0: 480x640 (no detections), 84.4ms
# Speed: 1.9ms preprocess, 84.4ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# No objects detected.
#
# 0: 480x640 (no detections), 89.4ms
# Speed: 1.6ms preprocess, 89.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# No objects detected.
#
# 0: 480x640 (no detections), 85.9ms
# Speed: 2.3ms preprocess, 85.9ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# No objects detected.
