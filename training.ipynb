# %%
from ultralytics import YOLO

# Load a model
model = YOLO("yolo11n.pt")

# Train the model
train_results = model.train(
    data=r"C:\Capstone\SignLang\yolo11\HandSignDetection.v1i.yolov11\data.yaml",  # path to dataset YAML
    epochs=5,  # number of training epochs
    imgsz=640,  # training image size
    device='cpu',  # device to run on, i.e. device=0 or device=0,1,2,3 or device=cpu
)
# Out:
# Ultralytics 8.3.70  Python-3.13.1 torch-2.6.0+cpu CPU (12th Gen Intel Core(TM) i5-12500H)
# ...

# %%
from ultralytics import YOLO

# Load a model
model = YOLO("runs/detect/train8/weights/best.pt")

# Perform object detection on an image
results = model("test_images/b1.jpg", save=True)
results[0].show()
# Out:
# image 1/1 C:\Capstone\SignLang\yolo11\test_images\b1.jpg: 640x640 1 O, 153.7ms
# Speed: 2.5ms preprocess, 153.7ms inference, 2.7ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs\segment\predict2

# %%
from ultralytics import YOLO
import cv2

# Load the trained YOLO model
model = YOLO("runs/detect/train8/weights/best.pt")

# Open the webcam (usually 0 for the default camera)
cap = cv2.VideoCapture(0)

# Check if the webcam is opened correctly
if not cap.isOpened():
    print("Error: Could not open webcam.")
    exit()

# Loop to capture frames from the webcam
while True:
    # Capture frame-by-frame
    ret, frame = cap.read()
    
    # If the frame was not captured successfully, break the loop
    if not ret:
        print("Error: Failed to capture frame.")
        break

    # Perform object detection on the current frame
    results = model(frame)  # Pass the frame to the YOLO model

    # Display the results (YOLO returns annotated images by default)
    annotated_frame = results[0].plot()  # Get the annotated frame

    # Show the annotated frame in a window
    cv2.imshow("YOLO Real-Time Detection", annotated_frame)

    # Break the loop if 'q' key is pressed
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release the webcam and close all OpenCV windows
cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 480x640 1 0, 135.3ms
# Speed: 3.9ms preprocess, 135.3ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 0, 108.9ms
# Speed: 2.5ms preprocess, 108.9ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 0, 104.2ms
# Speed: 2.0ms preprocess, 104.2ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 0, 112.2ms
# Speed: 1.9ms preprocess, 112.2ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 0, 93.3ms
# Speed: 1.8ms preprocess, 93.3ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 0, 95.6ms
# Speed: 2.0ms preprocess, 95.6ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 0, 95.2ms
# Speed: 2.0ms preprocess, 95.2ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 0, 132.6ms
# ...
